# %%
# import pandas as pd
# log_type = 'test'
# df = pd.read_csv(f"experiment_log_{log_type}.csv")

# df.tail(2)

# %%
# df.to_csv(f'./experiment_log_{log_type}.csv',index=False)

# %%
# import kaggle
# from kaggle.api.kaggle_api_extended import KaggleApi

# # Authenticate
# api = KaggleApi()
# api.authenticate()

# %%
# import pandas as pd
# from datetime import datetime
# import pytz

# # 1. Define the Singapore Timezone
# sg_tz = pytz.timezone('Asia/Singapore')

# # 2. Your date string in 'yyyy-mm-dd hh:mm:ss' format
# # Note: I corrected 'hh:ss:hh' to 'hh:mm:ss' (hours:minutes:seconds)
# date_string = '2026-01-18 00:00:00'

# # 3. Parse the string into a naive datetime object
# naive_date = datetime.strptime(date_string, '%Y-%m-%d %H:%M:%S')

# # 4. Localize it to Singapore Time, then convert to UTC
# # This ensures the comparison with Kaggle (UTC) is accurate
# cutoff_date_sg = sg_tz.localize(naive_date)
# cutoff_date_utc = cutoff_date_sg.astimezone(pytz.UTC)
# cutoff_date_naive = cutoff_date_utc.replace(tzinfo=None)
# print(cutoff_date_naive)

# # The competition ID/slug from the URL (e.g., 'titanic')
# comp_name = 'amex-default-prediction'

# # Retrieve submissions
# submissions = api.competition_submissions(comp_name)

# # Convert the list of submission objects into a Pandas DataFrame
# # Each object has attributes like 'ref', 'date', 'description', 'status', 'publicScore', 'privateScore'
# data = []
# for sub in submissions:
#     if sub.date > cutoff_date_naive:
#         data.append({
#             'date': sub.date,
#             'description': sub.description,
#             'status': sub.status,
#             'public_score': sub.public_score,
#             'private_score': sub.private_score
#         })

# df = pd.DataFrame(data)

# # Save to CSV
# df.to_csv('my_kaggle_submissions.csv', index=False)
# df.head(2)

# %%
# import json
# import pandas as pd

# # 1. Convert the description string into a Python dictionary/list
# # We use a lambda to handle potential nulls or malformed strings safely
# def parse_json(x):
#     try:
#         data = json.loads(x)
#         # If the JSON is wrapped in a list [{}], take the first element
#         return data[0] if isinstance(data, list) else data
#     except:
#         return {}

# # 2. Apply the parsing logic
# json_struct = df['description'].apply(parse_json)

# # 3. Create a new DataFrame from the JSON objects and join it back
# df_expanded = pd.json_normalize(json_struct)

# # 4. Combine with your original stats
# # We drop the original 'description' to keep it clean
# final_df = pd.concat([df.drop(columns=['description']), df_expanded], axis=1)

# final_df.head()

# %%
import kaggle
from kaggle.api.kaggle_api_extended import KaggleApi

# Authenticate
api = KaggleApi()
api.authenticate()

# %%
import pandas as pd
import json
from datetime import datetime
import pytz

def download_sub(date_string = '2026-03-13 00:00:01' ):
    # --- 1. Setup Cutoff (Example for Jan 17, 2026 SGT) ---
    sg_tz = pytz.timezone('Asia/Singapore')
    naive_date = datetime.strptime(date_string, '%Y-%m-%d %H:%M:%S')
    cutoff_date_utc = sg_tz.localize(naive_date).astimezone(pytz.UTC).replace(tzinfo=None)

    # --- 2. Fetch and Process ---
    submissions = api.competition_submissions('amex-default-prediction')
    processed_rows = []

    for sub in submissions:
        if sub.date > cutoff_date_utc:
            try:
                # Parse the JSON from the description
                desc_raw = json.loads(sub.description)
                # Handle list-wrapped JSON: [{"key": "val"}]
                desc_dict = desc_raw[0] if isinstance(desc_raw, list) else desc_raw
                
                # --- 3. RECONSTRUCT ROW IN JSON ORDER ---
                row = {}
                for key in desc_dict.keys():
                    if key == 'public_score':
                        # Use the official API score in the JSON's 'public_score' slot
                        row[key] = sub.public_score
                    elif key == 'private_score':
                        # Use the official API score in the JSON's 'private_score' slot
                        row[key] = sub.private_score
                    else:
                        # Keep the original JSON value for all other keys
                        row[key] = desc_dict[key]
                
                # Safety check: if the JSON didn't actually contain the score keys,
                # you can optionally append them here:
                if 'public_score' not in row: row['public_score'] = sub.public_score
                if 'private_score' not in row: row['private_score'] = sub.private_score

                processed_rows.append(row)
                
            except Exception as e:
                # Skip rows where description is not valid JSON
                continue

    # --- 4. Create DataFrame ---
    # Since Python 3.7+, dictionaries preserve insertion order, 
    # and Pandas will honor the order of the keys from the first row.
    final_df = pd.DataFrame(processed_rows)
    return final_df

# %%
final_df = download_sub(date_string = '2026-03-13 00:00:01' )
final_df = final_df.dropna(subset=['feature_w'])
final_df.to_csv(f'./experiment_log_submission.csv',index=False)
final_df
# Out:
#     stage stage_name                            model_specs  \
# 0       3    student  S3_student_original_v8_100pct_1e-3_42
# 1       2    distill  S2_distill_original_v8_100pct_5e-5_42
# 2       3    student   S3_student_original_v8_10pct_5e-5_42
# 3       2    distill   S2_distill_original_v8_10pct_5e-5_42
# 4       2    distill  S2_distill_original_v8_100pct_1e-3_42
# 5       1    teacher   S1_teacher_original_v8_10pct_5e-5_42
# 6       3    student   S3_student_original_v8_10pct_1e-4_42
# 7       2    distill   S2_distill_original_v8_10pct_1e-4_42
# 8       3    student    S3_student_original_v8_1pct_5e-5_42
# 9       1    teacher   S1_teacher_original_v8_10pct_1e-4_42
# 10      2    distill    S2_distill_original_v8_1pct_5e-5_42
# 11      3    student   S3_student_original_v8_10pct_5e-4_42
# 12      1    teacher    S1_teacher_original_v8_1pct_5e-5_42
# 13      2    distill  S2_distill_original_v8_100pct_1e-4_42
# 14      2    distill   S2_distill_original_v8_10pct_5e-4_42
# 15      3    student    S3_student_original_v8_1pct_1e-4_42
# 16      1    teacher  S1_teacher_original_v8_100pct_1e-3_42
# 17      2    distill    S2_distill_original_v8_1pct_1e-4_42
# 18      1    teacher    S1_teacher_original_v8_1pct_1e-4_42
# 19      1    teacher   S1_teacher_original_v8_10pct_5e-4_42
# 20      3    student    S3_student_original_v8_1pct_5e-4_42
# 21      3    student   S3_student_original_v8_10pct_1e-3_42
# 22      2    distill    S2_distill_original_v8_1pct_5e-4_42
# 23      2    distill   S2_distill_original_v8_10pct_1e-3_42
# 24      1    teacher    S1_teacher_original_v8_1pct_5e-4_42
# 25      2    distill   S2_distill_original_v8_10pct_5e-5_42
# 19        True         None  None  2026-03-13 07:04:38  2026-03-13 07:26:58
# 20        True         None  None  2026-03-13 06:43:57  2026-03-13 07:01:25
# 21        True         None  None  2026-03-13 06:30:33  2026-03-13 06:50:35
# 22        True         None  None  2026-03-13 06:22:02  2026-03-13 06:41:49
# 23        True         None  None  2026-03-13 05:57:56  2026-03-13 06:18:23
# 24        True         None  None  2026-03-13 05:53:50  2026-03-13 06:16:25
# 25        True         None  None  2026-03-13 05:49:06  2026-03-13 05:51:32
# 26        True         None  None  2026-03-13 05:31:36  2026-03-13 05:40:22
# 27        True         None  None  2026-03-13 05:20:19  2026-03-13 05:22:47
# 28        True         None  None  2026-03-13 05:13:20  2026-03-13 05:21:14
# 29        True         None  None  2026-03-13 05:03:34  2026-03-13 05:11:29
# 30        True         None  None  2026-03-13 04:52:04  2026-03-13 04:54:27
# 31        True         None  None  2026-03-13 04:42:43  2026-03-13 04:51:33
# 32        True         None  None  2026-03-13 04:29:54  2026-03-13 04:32:23
#
#     public_score private_score
# 0        0.78668       0.79706
# 1        0.79018       0.80119
# 2        0.77410       0.78390
# 3        0.77343       0.78432
# 4        0.78816       0.79809
# 5        0.77433       0.78512
# 6        0.77512       0.78563
# 7        0.77521       0.78583
# 8        0.74654       0.75601
# 9        0.77367       0.78303
# 10       0.74084       0.74962
# 11       0.77502       0.78536
# 12       0.74699       0.75770
# 13       0.79112       0.80147
# 14       0.77546       0.78453
# 15       0.74960       0.75966
# 16       0.78730       0.79717
# 17       0.75081       0.76131
# 18       0.75303       0.76319
# 19       0.77400       0.78401
# 20       0.74859       0.75947
# 21       0.77427       0.78570
# 22       0.75169       0.76271
# 23       0.77448       0.78425
# 24       0.75201       0.76193
# 25       0.77361       0.78416
# 26       0.77513       0.78419
# 27       0.77526       0.78506
# 28       0.74776       0.75998
# 29       0.75217       0.76232
# 30       0.77559       0.78490
# 31       0.75280       0.76283
# 32       0.77464       0.78432
#
# [33 rows x 25 columns]

# %%
# 0. Filter Specific Rows
# final_df2 = final_df[final_df['remark'] == 'only forecast loss'].copy()
final_df2 = final_df[final_df['remark'].str.contains('T=1', na=False)].copy()



# 1. Ensure numeric type
final_df2['private_score'] = pd.to_numeric(final_df2['private_score'], errors='coerce')
final_df2.tail(2)
# Out:
#     stage stage_name                           model_specs  \
# 30      2    distill  S2_distill_original_v8_10pct_5e-4_42
# 32      2    distill  S2_distill_original_v8_10pct_1e-3_42
#
#                log_time  feature_w  fcst_w  recon_w  att_w  distill_w    lr  \
# 30  2026-03-13 04:54:27        0.5     1.0      0.0    0.5        1.0  5e-4
# 32  2026-03-13 04:32:23        0.5     1.0      0.0    0.5        1.0  1e-3
#
#     ... emb_version temperature                     remark  is_predict  \
# 30  ...          v8         1.0  Stage 2 Distillation, T=1        True
# 32  ...          v8         1.0  Stage 2 Distillation, T=1        True
#
#     amex_metric   AUC      test_start_time        test_end_time  public_score  \
# 30         None  None  2026-03-13 04:52:04  2026-03-13 04:54:27       0.77559
# 32         None  None  2026-03-13 04:29:54  2026-03-13 04:32:23       0.77464
#
#    private_score
# 30       0.78490
# 32       0.78432
#
# [2 rows x 25 columns]

# %%
# 1. Sort by score (descending)
# 2. Group by your breakdown
# 3. Take top n of each group
cols = [    'remark',
            'lr', 
            'sampling']

(final_df2.sort_values('sampling', ascending=False)
         .groupby(cols)
         .head(2)
         [cols + ['private_score']] # Select just the columns you want to see
)
# Out:
#                        remark    lr sampling  private_score
# 25  Stage 2 Distillation, T=1  5e-5    10pct        0.78416
# 27  Stage 2 Distillation, T=1  1e-4    10pct        0.78506
# 30  Stage 2 Distillation, T=1  5e-4    10pct        0.78490
# 32  Stage 2 Distillation, T=1  1e-3    10pct        0.78432
# 1   Stage 2 Distillation, T=1  5e-5   100pct        0.80119
# 13  Stage 2 Distillation, T=1  1e-4   100pct        0.80147

# %%
# 0. Filter Specific Rows
final_df2 = final_df[final_df['remark'].str.contains('Amodel_CAI', na=False)].copy()

# 1. Ensure numeric type
final_df2['private_score'] = pd.to_numeric(final_df2['private_score'], errors='coerce')
final_df2.tail(2)
# Out:
#                                           model_specs             log_time  \
# 11  original_10pct_0.001_42_128_3_512_1_0.2_0.01_1...  2026-02-08 17:28:25
# 12  original_1pct_0.001_42_128_3_512_1_0.2_0.01_1....  2026-02-08 17:17:21
#
#     feature_w  fcst_w  recon_w  att_w     lr sampling data_type  seed  ...  \
# 11       0.01     1.0      0.5   0.01  0.001    10pct  original    42  ...
# 12       0.01     1.0      0.5   0.01  0.001     1pct  original    42  ...
#
#     emb_version                               remark is_predict amex_metric  \
# 11           v2  only forecast loss, test Amodel_CAI       True        None
# 12           v2  only forecast loss, test Amodel_CAI       True        None
#
#      AUC      test_start_time        test_end_time test_duration public_score  \
# 11  None  2026-02-08 17:21:09  2026-02-08 17:28:25        436078      0.77368
# 12  None  2026-02-08 17:10:04  2026-02-08 17:17:21        436849      0.75119
#
#     private_score
# 11        0.78338
# 12        0.76156
#
# [2 rows x 22 columns]

# %%
# 1. Sort by score (descending)
# 2. Group by your breakdown
# 3. Take top n of each group
cols = [    'feature_w', 'fcst_w', 'recon_w', 'att_w',
            # 'lr', 
            'sampling']

(final_df2.sort_values('sampling', ascending=False)
         .groupby(cols)
         .head(2)
         [cols + ['private_score']] # Select just the columns you want to see
)
# Out:
#    feature_w  fcst_w  recon_w  att_w sampling  private_score
# 5       0.01     1.0      0.5   0.01     1pct        0.73369
# 6       0.01     1.0      0.5   0.01     1pct        0.76188
# 1       0.01     1.0      0.5   0.01    10pct        0.78192
# 2       0.01     1.0      0.5   0.01    10pct        0.78513
# 0       0.01     1.0      0.5   0.01   100pct        0.79877
